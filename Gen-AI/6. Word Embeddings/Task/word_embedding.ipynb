# %% [markdown]
# ## GOOGLE Collab :
#
# https://colab.research.google.com/drive/1NVz-16NfOf_g8pcf1PqoTuky_5A2SnRu?usp=sharing

# %%
# !pip install model2vec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 13.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 14.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [model2vec]/6 [model2vec]e-hub]
# ...

# %%
from model2vec import StaticModel

model = StaticModel.from_pretrained("minishlab/potion-base-8M")
# Out:
# model.safetensors:   0%|          | 0.00/30.2M [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/202 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
embeddings1 = model.encode(["I like my dog"])
# embeddings2 = model.encode(["I love my dog"])
# embeddings3 = model.encode(["I adore my dog"])

# embeddings4 = model.encode(["Hello, how are you?"])
# embeddings5 = model.encode(["Hey, how's it going?"])
# embeddings6 = model.encode(["Hi, what's up?"])

# embeddings7 = model.encode(["I love watching cricket"])
# embeddings8 = model.encode(["I enjoyed watching the world cup"])
# embeddings9 = model.encode(["I like watching cricket matches"])

# %%
embeddings1
# Out:
# array([[-1.59884229e-01, -2.42282361e-01, -5.09661697e-02,
#          6.12658309e-03,  1.03232637e-02,  6.41653836e-02,
#         -7.42688403e-02, -5.11142015e-02,  5.54367341e-02,
#         -8.72432590e-02,  1.88748673e-01,  1.98447541e-03,
#          1.51814327e-01,  5.21518476e-02,  7.03964308e-02,
#          4.92927656e-02,  1.06337322e-02,  4.54029590e-02,
#          3.01207211e-02, -3.64367403e-02,  1.40412673e-02,
#         -9.11846198e-03,  1.03379317e-01, -1.02665506e-01,
#          3.27977724e-02,  1.44286584e-02,  6.04828186e-02,
#         -5.71417361e-02,  5.49565963e-02,  1.86150342e-01,
#         -6.83921352e-02, -1.28676612e-02, -2.46712677e-02,
#          1.49617255e-01,  4.03515473e-02,  5.84644862e-02,
#          7.30511621e-02, -4.10389714e-02, -8.68533738e-03,
#         -1.09516583e-01, -1.91505961e-02,  1.79216601e-02,
#         -4.45670523e-02, -2.00854391e-02,  1.00328159e-02,
#         -7.62326038e-03, -3.11087817e-02, -4.17116098e-02,
# ...

# %%
embeddings2
# Out:
# array([[-9.82425511e-02, -2.39080742e-01, -5.56836165e-02,
#          7.16559738e-02, -5.10019325e-02,  1.89424768e-01,
#         -9.99569520e-02,  2.15486977e-02,  3.63045074e-02,
#         -5.49622849e-02,  1.43254995e-01, -9.91448946e-03,
#          1.19844593e-01,  6.05500154e-02,  8.94568190e-02,
#          2.65863668e-02,  1.32465083e-02, -1.29101016e-02,
#          3.43338773e-02, -1.65054183e-02,  4.61341254e-02,
#         -2.82077678e-02,  1.66314512e-01, -1.58733442e-01,
#          7.02723116e-02,  2.31410917e-02,  9.28441137e-02,
#         -2.13675629e-02,  4.22669686e-02,  1.85118735e-01,
#         -1.31393790e-01, -5.97157292e-02,  2.18484141e-02,
#          5.52224107e-02,  6.19531795e-02,  4.62512020e-03,
#          6.65078312e-02, -4.88897301e-02, -4.09102514e-02,
#         -4.01144773e-02, -1.37760565e-02,  2.37842854e-02,
#         -7.06273643e-03, -4.79646884e-02, -1.41988997e-03,
#         -2.65940893e-02, -9.74894967e-03, -2.12469101e-02,
# ...
